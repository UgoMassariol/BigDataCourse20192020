# %% [markdown]
# # Propaganda, start the `spark` session
#
# > For SQL users, Spark SQL provides state-of-the-art SQL performance and maintains compatibility with Shark/Hive. In particular, like Shark, Spark SQL supports all existing Hive data formats, user-defined functions (UDF), and the Hive metastore.
#
# > For Spark users, Spark SQL becomes the narrow-waist for manipulating (semi-) structured data as well as ingesting data from sources that provide schema, such as JSON, Parquet, Hive, or EDWs. It truly unifies SQL and sophisticated analysis, allowing users to mix and match SQL and more imperative programming APIs for advanced analytics.
#
# > For open source hackers, Spark SQL proposes a novel, elegant way of building query planners. It is incredibly easy to add new optimizations under this framework.
#
# > Internally, a structured query is a Catalyst tree of (logical and physical) relational operators and expressions.

# %%
# import the usual suspects
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path
import sys
import timeit

# %matplotlib inline
import seaborn as sns

sns.set_context("notebook", font_scale=1.2)

# %% [markdown]
# During the session, we will use classes and functions exported by `pyspark`

# %%
# spark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import Window
from pyspark.sql.functions import col, mean
import pyspark.sql.functions as fn
from pyspark.sql.catalog import Catalog
from pyspark.sql.types import StructType, StructField
from pyspark.sql.types import IntegerType, StringType

# %% [markdown]
# Start the `SparkSession`

# %%
conf = SparkConf().setAppName("Spark SQL Illustrations")
sc = SparkContext(conf=conf)

spark = (SparkSession
    .builder
    .appName("Spark SQL")
    .getOrCreate()
)

# %% [markdown]
# US Baby Names 1880-2017
# =======================
#
#
# Description
# : US baby names provided by the SSA.
#
# This dataset contains all names used
# for at least 5 children of either sex during a year.
#
#
# The file is made of `1924665` lines and  4 columns.
#
# ```
# |-- name: string (nullable = true)
#     |-- n: integer (nullable = true)
#     |-- sex: string (nullable = true)
#     |-- year: integer (nullable = true)
# ```
#
# Each row indicates for a given name, sex, and year the number of babies
# of the given sex who were given that name during the given year. Names
# with less than 5 occurrences during the year were note recorded.
#
# |    name|  n|sex|year|
# |:--------|:---:|:---:|:----:|
# |  Emilia|112|  F|1985|
# |   Kelsi|112|  F|1985|
# |  Margot|112|  F|1985|
# |  Mariam|112|  F|1985|
# |Scarlett|112|  F|1985|
#
# First, we download the data if it's not there yet

# %%
import requests, zipfile, io
from pathlib import Path

path = Path('babynames_short.csv')
if not path.exists():
    url = "https://stephanegaiffas.github.io/big_data_course/data/babynames_short.csv.zip"
    r = requests.get(url)
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall(path='./')

# %% [markdown]
# Load `babynames` from a `csv` file

# %%
df_sp = spark.read\
             .format('csv')\
             .option("header", "true")\
             .option("mode", "FAILFAST")\
             .option("inferSchema", "true")\
             .option("sep", ",")\
             .load("babynames_short.csv")

df_sp.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- year: double (nullable = true)

# %% [markdown]
# Ensure that the dataframe has the following schema:
#
#     root
#         |-- name: string (nullable = true)
#         |-- n: integer (nullable = true)
#         |-- sex: string (nullable = true)
#         |-- year: integer (nullable = true)

# %%
df_sp = df_sp.withColumn("year", df_sp["year"].cast("integer"))

df_sp.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- year: integer (nullable = true)

# %% [markdown]
# SQL versus spark-Dataframe API
# =================================
#
# >  Dataset API vs SQL
#
# > Spark SQL supports two "modes" to write structured queries: Dataset API and SQL. SQL Mode is used to express structured queries using SQL statements using SparkSession.sql operator, expr standard function and spark-sql command-line tool.
#
# > Some structured queries can be expressed much easier using Dataset API, but there are some that are only possible in SQL. In other words, you may find mixing Dataset API and SQL modes challenging yet rewarding.
#
# > What is important, and one of the reasons why Spark SQL has been so successful, is that there is no performance difference between the modes. Whatever mode you use to write your structured queries, they all end up as a tree of Catalyst relational data structures. And, yes, you could consider writing structured queries using Catalyst directly, but that could quickly become unwieldy for maintenance (i.e. finding Spark SQL developers who could be comfortable with it as well as being fairly low-level and therefore possibly too dependent on a specific Spark SQL version).
#
# Warmup:  compute the 10 most popular names given to babies in year 2000.
# ======================================================================
#
# ## Using `spark.sql()`
#
# In order to use mode `sql`, create a temporary view from the `DataFrame`.
#
# 1. What are temporary views made of?
# 1. Are there other kind of views in spark's world?

# %% [markdown]
# A temporary view is a table on which SQL queries can be made and
# are stored in database global_temp

# %%
df_sp.createOrReplaceTempView("babynames")
Catalog(spark).listTables()
# Out:
# [Table(name='babynames', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
# TODO: 
Catalog(spark).listTables()
# Out:
# [Table(name='babynames', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %% [markdown]
# ## A query is a plain SQL query embodied in a string.

# %%
query = """
SELECT name, sex, n
FROM babynames
WHERE year == {0}
ORDER BY n DESC
LIMIT 10
"""
spark.sql(query.format(2000)).show()
# Out:
# +-----------+---+-----+
# |       name|sex|    n|
# +-----------+---+-----+
# |      Jacob|  M|34471|
# |    Michael|  M|32035|
# |    Matthew|  M|28572|
# |     Joshua|  M|27538|
# |      Emily|  F|25953|
# |Christopher|  M|24931|
# |   Nicholas|  M|24652|
# |     Andrew|  M|23639|
# |     Hannah|  F|23080|
# |     Joseph|  M|22825|
# +-----------+---+-----+

# %% [markdown]
# > This phrasing is not consistent with the DRY principle. Fix this using formatted strings.
#
# ## Using the dataframe/dataset API
#
# This can also be done using Spark SQL API.
#
# ### Pedestrian approach
#
# 1. First select `10` most popular names for girls in year `2000`, define `spark` dataframe
# `top10_2000_f`.
# 1. Does the definition of `top10_2000_f` involve _transformations_, _actions_ or both?
# 1. What is the type of the result returned by `top10_2000_f.take(2)`? the type of elements of the result?

# %%
query431 = """
SELECT name, sex, n
FROM babynames
WHERE year == {0}
AND sex == "{1}"
ORDER BY n DESC
LIMIT 10
"""
top10_2000_f = spark.sql(query431.format(2000,'F'))
top10_2000_f.show()
# Out:
# +---------+---+-----+
# |     name|sex|    n|
# +---------+---+-----+
# |    Emily|  F|25953|
# |   Hannah|  F|23080|
# |  Madison|  F|19967|
# |   Ashley|  F|17997|
# |    Sarah|  F|17697|
# |   Alexis|  F|17629|
# | Samantha|  F|17266|
# |  Jessica|  F|15709|
# |Elizabeth|  F|15094|
# |   Taylor|  F|15078|
# +---------+---+-----+

# %% [markdown]
# 1. Do the same thing for boys.

# %%
top10_2000_m = spark.sql(query431.format(2000,'M'))
top10_2000_m.show()
# Out:
# +-----------+---+-----+
# |       name|sex|    n|
# +-----------+---+-----+
# |      Jacob|  M|34471|
# |    Michael|  M|32035|
# |    Matthew|  M|28572|
# |     Joshua|  M|27538|
# |Christopher|  M|24931|
# |   Nicholas|  M|24652|
# |     Andrew|  M|23639|
# |     Joseph|  M|22825|
# |     Daniel|  M|22312|
# |      Tyler|  M|21503|
# +-----------+---+-----+

# %% [markdown]
# 1. Compute the _union_ of the two spark dataframes. Store the result in
# dataframe `top10_2000`

# %%
query43 = """
({0}) UNION ({1})
""".format(query431.format(2000,'F'), query431.format(2000,'M'))

top10_2000 = spark.sql(query43).show()
# Out:
# +-----------+---+-----+
# |       name|sex|    n|
# +-----------+---+-----+
# |  Elizabeth|  F|15094|
# |      Emily|  F|25953|
# |Christopher|  M|24931|
# |     Joseph|  M|22825|
# |      Tyler|  M|21503|
# |     Andrew|  M|23639|
# |     Ashley|  F|17997|
# |     Daniel|  M|22312|
# |     Hannah|  F|23080|
# |    Michael|  M|32035|
# |   Samantha|  F|17266|
# |      Jacob|  M|34471|
# |     Alexis|  F|17629|
# |    Jessica|  F|15709|
# |      Sarah|  F|17697|
# |     Taylor|  F|15078|
# |    Matthew|  M|28572|
# |    Madison|  F|19967|
# |   Nicholas|  M|24652|
# |     Joshua|  M|27538|
# +-----------+---+-----+

# %% [markdown]
# ### Do it again, complying  with DRY principle

# %%
top10_2000 = top10_2000_f.union(top10_2000_m)

top10_2000.show()
# Out:
# +-----------+---+-----+
# |       name|sex|    n|
# +-----------+---+-----+
# |      Emily|  F|25953|
# |     Hannah|  F|23080|
# |    Madison|  F|19967|
# |     Ashley|  F|17997|
# |      Sarah|  F|17697|
# |     Alexis|  F|17629|
# |   Samantha|  F|17266|
# |    Jessica|  F|15709|
# |  Elizabeth|  F|15094|
# |     Taylor|  F|15078|
# |      Jacob|  M|34471|
# |    Michael|  M|32035|
# |    Matthew|  M|28572|
# |     Joshua|  M|27538|
# |Christopher|  M|24931|
# |   Nicholas|  M|24652|
# |     Andrew|  M|23639|
# |     Joseph|  M|22825|
# |     Daniel|  M|22312|
# |      Tyler|  M|21503|
# +-----------+---+-----+

# %% [markdown]
# Name portfolio through ages
# ===========================
#
# 1. Compute for each year and sex the number of distinct names given that year.

# %%
query51= """
SELECT year, sex, count(name) AS nb_names
FROM babynames
GROUP BY year, sex
ORDER BY year, sex
"""

nb_names_year_sex = spark.sql(query51)
nb_names_year_sex.show(5)
# Out:
# +----+---+--------+
# |year|sex|nb_names|
# +----+---+--------+
# |1880|  F|     942|
# |1880|  M|    1058|
# |1881|  F|     938|
# |1881|  M|     997|
# |1882|  F|    1028|
# +----+---+--------+
# only showing top 5 rows

# %% [markdown]
# 1. Plot the evolution of the number of distinct names as a function of `year`.
# Use some aesthetics to distinguish sexes.

# %%
nb_names_year_sex_pd = nb_names_year_sex.toPandas()

sns.set()

g = sns.lineplot(x = "year",
                 y = "nb_names",
                 hue = "sex",
                 palette='Set1',
                 data = nb_names_year_sex_pd)

plt.show()

# %% [markdown]
# Assessing popularity through time
# =================================
#
# 1. For each year and sex, compute the total number of births
# 1. Plot the evolution of the sex ratio over time
# 1. For each year, sex, and name compute the percentage of newborns
# given that name for that given year.
#
#
# > Use `Window` functions.

# %%
query60= """
SELECT year, sex, sum(n) AS n_birth
FROM babynames
GROUP BY year, sex
ORDER BY year, sex
"""

n_births_year_sex = spark.sql(query60)
n_births_year_sex
# Out:
# DataFrame[year: int, sex: string, n_birth: bigint]

# %%
sex_ratio=n_births_year_sex.groupby("year")\
            .pivot("sex")\
            .sum("n_birth")\
            .withColumn("sex_ratio", fn.round(col("M")/col("F"), 2))\
            .orderBy(col("sex_ratio"))

sex_ratio_pd = sex_ratio.toPandas()

sns.set()
g = sns.lineplot(x = "year",
                 y = "sex_ratio",
                 data = sex_ratio_pd,
                 palette = "Set1")
# %%

# %%
# 3. For each year, sex, and name compute the percentage of newborns given that name for that given year.

window = Window.partitionBy('year', 'sex')

df_perc = df_sp.withColumn('percentage', 
                           fn.round(  100 * fn.col('n')/   
                                            fn.sum('n').over(window),
                                            10
                                            )
                          )\
                .orderBy("year","sex", "n")

df_perc.show()
# Out:
# +----------+---+---+----+------------+
# |      name|  n|sex|year|  percentage|
# +----------+---+---+----+------------+
# |  Delphine|  5|  F|1880|0.0054949282|
# |    Caddie|  5|  F|1880|0.0054949282|
# |    Delila|  5|  F|1880|0.0054949282|
# |       Ana|  5|  F|1880|0.0054949282|
# |     Bulah|  5|  F|1880|0.0054949282|
# |     Clair|  5|  F|1880|0.0054949282|
# |   Corrine|  5|  F|1880|0.0054949282|
# |     Adina|  5|  F|1880|0.0054949282|
# |      Alys|  5|  F|1880|0.0054949282|
# |    Arthur|  5|  F|1880|0.0054949282|
# |    Birtha|  5|  F|1880|0.0054949282|
# |     Celie|  5|  F|1880|0.0054949282|
# | Charlotta|  5|  F|1880|0.0054949282|
# |Concepcion|  5|  F|1880|0.0054949282|
# |  Cordella|  5|  F|1880|0.0054949282|
# |    Adelle|  5|  F|1880|0.0054949282|
# |     Edgar|  5|  F|1880|0.0054949282|
# |  Adrienne|  5|  F|1880|0.0054949282|
# | Albertine|  5|  F|1880|0.0054949282|
# |  Araminta|  5|  F|1880|0.0054949282|
# +----------+---+---+----+------------+
# only showing top 20 rows

# %% [markdown]
# 1. Compute for each year, sex and name  the `row_number`, `rank`, and `dense_rank`
# of the name within that year and sex category, when names are sorted by increasing popularity.

# %%
              
window63=window.orderBy(df_sp.n.desc())

rank = fn.rank().over(window63)
dense_rank = fn.dense_rank().over(window63)
row_number = fn.row_number().over(window63)

df_rank = df_sp\
    .withColumn('rank', rank)\
    .withColumn('dense_rank', dense_rank)\
    .withColumn('row_number', row_number)\
    .orderBy("year")

df_rank.show()
# Out:
# +-------+----+---+----+----+----------+----------+
# |   name|   n|sex|year|rank|dense_rank|row_number|
# +-------+----+---+----+----+----------+----------+
# |    Joe| 731|  M|1880|  20|        20|        20|
# |  Harry|2152|  M|1880|  12|        12|        12|
# |  Louis| 828|  M|1880|  19|        19|        19|
# | Joseph|2632|  M|1880|   7|         7|         7|
# | Edward|2364|  M|1880|  11|        11|        11|
# |   Fred|1569|  M|1880|  15|        15|        15|
# |  David| 869|  M|1880|  18|        18|        18|
# |  James|5927|  M|1880|   3|         3|         3|
# |  Frank|3242|  M|1880|   6|         6|         6|
# |  Henry|2444|  M|1880|   9|         9|         9|
# | Robert|2415|  M|1880|  10|        10|        10|
# | Walter|1755|  M|1880|  13|        13|        13|
# | Arthur|1599|  M|1880|  14|        14|        14|
# | Albert|1493|  M|1880|  16|        16|        16|
# | Samuel|1024|  M|1880|  17|        17|        17|
# |   John|9655|  M|1880|   1|         1|         1|
# |William|9532|  M|1880|   2|         2|         2|
# |Charles|5348|  M|1880|   4|         4|         4|
# | George|5126|  M|1880|   5|         5|         5|
# | Thomas|2534|  M|1880|   8|         8|         8|
# +-------+----+---+----+----+----------+----------+
# only showing top 20 rows

# %% [markdown]
# Evolution of top popular names through the century
# ==================================================
#
#
# 1. For each sex, select the ten most popular names in year 2000, and plot the proportion
# of newborns given that name over time. Take into account that some names might have
# zero occurrence during certain years.

# %%
# TODO:

df_top10_perc = df_perc\
        .filter(df_perc.percentage > 0)\
        .join(
                top10_2000.select('name','sex'), 
                ["sex","name"],
                'inner'
                )\
        .orderBy("year","sex")\
        .toPandas()

df_top10_perc.head()

sns.set()
g = sns.relplot( x       = "year",
                 y       = "percentage",
                 col     ="sex",
                 hue     ="name",
                 kind    ="line",
                 height  =8, 
                 aspect  =.90,
                 data    = df_top10_perc,
                 palette = "Set1"
               )

g.set(yscale="log")

# %% [markdown]
# 1. Use `explain()` to determine the joining strategy used by spark.
#
#
# Plot  the popularity of each of the top ten achievers from year 2000 with respect to time
# ==================================================================================

# %%
# %%
top10_rank_glob = df_rank\
        .join(
            top10_2000.select('name','sex'), 
            ["sex","name"],
            'inner'
            )


top10_rank= top10_rank_glob.withColumn('rank',
                                        fn.rank()\
                                            .over(
                                    window.orderBy( top10_rank_glob.rank.desc() )
                                                 )
                                      )


g = sns.relplot(x = "year",
                 y = "rank",
                 col="sex",
                 hue="name",
                 kind="line",
                 height=8, 
                 aspect=.90,
                 data = top10_rank.toPandas(),
                 palette = "Set1")

# %% [markdown]
# Plot the total popularity of the top ten achievers from year 2000 with respect to time
# ==================================================================================

# %%
# %%
g = sns.relplot(x = "year",
                 y = "rank",
                 col="sex",
                 hue="name",
                 kind="line",
                 height=8, 
                 aspect=.90,
                 data = top10_rank_glob.toPandas(),
                 palette = "Set1")
g.set(yscale="log")
# %%

# %% [markdown]
# Plot lorenz curves
# =====================
#
# Every year, the name counts define a discrete probability distribution.
# This distribution, just as income or wealth distribution,
# is (usually) far from being uniform. We want to assess how uneven it is.
# We use the tools developed in econometrics.
#
# Without loss of generality, that we handle a distribution over $1, \ldots, n$
# where $n$ is the number of distinct names given during a year.
# We assume that frequencies $p_1, p_2, \ldots, p_n$ are given in ascending order.
#
# The Lorenz function maps $[0, 1] \to [0, 1]$.
# $$L(x) = \sum_{i=1}^{\lfloor nx \rfloor} p_i$$.
#
# 1. Design a query that adds a column "lorenz" to the dataframe , and for each
# row computes the value of the Lorenz function defined by `year`  and `sex`.

# %%
window10 = window.orderBy('percentage').rowsBetween(Window.unboundedPreceding, 0)

df_lorenz = df_perc.withColumn('total names by year sex', fn.count("name").over(window))\
                   .withColumn('lorenz', fn.round(fn.sum('percentage').over(window10) / 100, 10))\
                   .orderBy('year','sex','lorenz')

# %%
df_lorenz.show()
# Out:
# +----------+---+---+----+------------+-----------------------+------------+
# |      name|  n|sex|year|  percentage|total names by year sex|      lorenz|
# +----------+---+---+----+------------+-----------------------+------------+
# |    Adelle|  5|  F|1880|0.0054949282|                    942|  5.49493E-5|
# |     Adina|  5|  F|1880|0.0054949282|                    942| 1.098986E-4|
# |  Adrienne|  5|  F|1880|0.0054949282|                    942| 1.648478E-4|
# | Albertine|  5|  F|1880|0.0054949282|                    942| 2.197971E-4|
# |      Alys|  5|  F|1880|0.0054949282|                    942| 2.747464E-4|
# |       Ana|  5|  F|1880|0.0054949282|                    942| 3.296957E-4|
# |  Araminta|  5|  F|1880|0.0054949282|                    942|  3.84645E-4|
# |    Arthur|  5|  F|1880|0.0054949282|                    942| 4.395943E-4|
# |    Birtha|  5|  F|1880|0.0054949282|                    942| 4.945435E-4|
# |     Bulah|  5|  F|1880|0.0054949282|                    942| 5.494928E-4|
# |    Caddie|  5|  F|1880|0.0054949282|                    942| 6.044421E-4|
# |     Celie|  5|  F|1880|0.0054949282|                    942| 6.593914E-4|
# | Charlotta|  5|  F|1880|0.0054949282|                    942| 7.143407E-4|
# |     Clair|  5|  F|1880|0.0054949282|                    942| 7.692899E-4|
# |Concepcion|  5|  F|1880|0.0054949282|                    942| 8.242392E-4|
# |  Cordella|  5|  F|1880|0.0054949282|                    942| 8.791885E-4|
# |   Corrine|  5|  F|1880|0.0054949282|                    942| 9.341378E-4|
# |    Delila|  5|  F|1880|0.0054949282|                    942| 9.890871E-4|
# |  Delphine|  5|  F|1880|0.0054949282|                    942|0.0010440364|
# |     Dosha|  5|  F|1880|0.0054949282|                    942|0.0010989856|
# +----------+---+---+----+------------+-----------------------+------------+
# only showing top 20 rows

# %% [markdown]
# 1. Design a function that takes as input a `year` and plots the Lorenz curve
# for that year for both sexes.

# %%
df_lorenz2 = df_lorenz.withColumn('cum_proportion', 
                                                 fn.row_number()
                                                 .over(window.orderBy('lorenz'))/
                                                 fn.count("name").over(window) 
                                )\
                     .orderBy('year','sex','lorenz')

def lorenz_curve(y):
    
    selection = "year ==" + str(y)
    
    return sns.relplot(x       = 'cum_proportion',
                       y       = "lorenz",
                       col     = "sex",
                       kind    ="line",
                       height  = 8, 
                       aspect  =.90,
                       data    = df_lorenz2.where(selection).toPandas(),
                       palette = "Set1")

lorenz_curve(2015)

# %% [markdown]
# Gini index
# ==========
#
# The [Gini index](https://en.wikipedia.org/wiki/Gini_coefficient) is twice the surface of the area comprised between curves $y=x$
# and $y=L(x)$.
#
# Choose a formula that allows you to compute it efficiently.
#
# $$G={\frac {2\sum _{i=1}^{n}iy_{i}}{n\sum _{i=1}^{n}y_{i}}}-{\frac {n+1}{n}}.$$
#
# 1. Design a query that computes the Gini index of the `babynames` distribution
# for every `year` and `sex`.
#
# 1. Plot Gini index over time

# %%
df_gini = df_sp.withColumn('partial_gini', 2 * fn.row_number().over(window.orderBy('n')) * fn.col('n'))\
               .groupBy("year","sex")\
               .agg((fn.avg('partial_gini') / fn.sum('n') - (1+1/fn.count('n'))).alias('gini'))\
               .orderBy('year','sex')

# %%
df_gini.show()
# Out:
# +----+---+------------------+
# |year|sex|              gini|
# +----+---+------------------+
# |1880|  F|0.8097632880604917|
# |1880|  M|0.8511119527839124|
# |1881|  F|0.8096277724341281|
# |1881|  M| 0.845378337448246|
# |1882|  F|0.8189652429138425|
# |1882|  M|0.8508524117247931|
# |1883|  F|0.8196854114668959|
# |1883|  M|0.8454214653051835|
# |1884|  F| 0.827445370535457|
# |1884|  M|0.8496568431558733|
# |1885|  F| 0.827787128437631|
# |1885|  M|0.8445218147691613|
# |1886|  F|0.8332870458584818|
# |1886|  M|0.8465949810295563|
# |1887|  F|0.8325242571530609|
# |1887|  M|0.8415735146910239|
# |1888|  F|0.8431415403619023|
# |1888|  M|0.8479599716614603|
# |1889|  F|0.8419074674702531|
# |1889|  M|0.8427610965111705|
# +----+---+------------------+
# only showing top 20 rows

# %%
sns.relplot(x = "year",
             y = "gini",
             hue="sex",
             kind="line",
             height=8, 
             aspect=.90,
             data = df_gini.toPandas(),
             palette = "Set1")

# %% [markdown]
# Close the door, leave work area clean
# =====================================

# %%
spark.stop()
